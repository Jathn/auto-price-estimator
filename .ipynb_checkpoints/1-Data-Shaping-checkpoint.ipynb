# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
n1 = plt.cm.cividis(np.linspace(0.2, 1.6, 10))
n2 = plt.cm.viridis(np.linspace(0.2, 0.8, 10))
c1 = plt.cm.twilight_shifted(np.linspace(0.2, 1.2, 30))
c2 = plt.cm.Greys(np.linspace(0.5, 2, 20))
b1 = ['Orange', 'Grey']
b2 = ['Grey', 'Orange']

# %%
car_data = pd.read_csv("vehicles.csv")

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB

# %%
car_data.drop(columns = ['county', 'size', 'cylinders', 'condition', 'posting_date', 'VIN', 'id', 'url', 'state', 'region', 'region_url', 'image_url', 'title_status', 'description'], inplace=True)

# %%
car_data.dropna(inplace=True)

# %%
car_data.head(20)
# Out:
#     price    year manufacturer                        model    fuel  odometer  \
# 31  15000  2013.0         ford                    f-150 xlt     gas  128000.0
# 32  27990  2012.0          gmc  sierra 2500 hd extended cab     gas   68696.0
# 33  34590  2016.0    chevrolet        silverado 1500 double     gas   29499.0
# 34  35000  2019.0       toyota                       tacoma     gas   43000.0
# 35  29990  2016.0    chevrolet        colorado extended cab     gas   17302.0
# 36  38590  2011.0    chevrolet         corvette grand sport     gas   30237.0
# 38  32990  2017.0         jeep     wrangler unlimited sport     gas   30041.0
# 40  30990  2016.0    chevrolet        colorado crew cab z71   other   34940.0
# 42  37990  2016.0    chevrolet           camaro ss coupe 2d     gas    9704.0
# 45  27990  2018.0       nissan     frontier crew cab pro-4x     gas   37332.0
# 49  32990  2020.0         jeep        wrangler sport suv 2d     gas   20581.0
# 54  31590  2019.0     cadillac             xt4 sport suv 4d   other   12102.0
# 55  19900  2004.0         ford              f250 super duty  diesel   88000.0
# 56  16590  2016.0         jeep        renegade sport suv 4d     gas   35835.0
# 59  14000  2012.0        honda                      odyssey     gas   95000.0
# 63  34990  2018.0         ford           mustang gt premium     gas   18650.0
# 65  22500  2001.0         ford                         f450  diesel  144700.0
# 68  29990  2014.0    chevrolet        silverado 1500 double     gas   26129.0
# 72  33990  2017.0         jeep    wrangler unlimited sahara   other   34152.0
# 73  15000  2017.0        dodge         charger rt 4dr sedan     gas   90000.0
#
#    transmission drive       type paint_color        lat       long
# 31    automatic   rwd      truck       black  32.592000 -85.518900
# 32        other   4wd     pickup       black  32.590000 -85.480000
# 33        other   4wd     pickup      silver  32.590000 -85.480000
# 34    automatic   4wd      truck        grey  32.601300 -85.443974
# 35        other   4wd     pickup         red  32.590000 -85.480000
# 36        other   rwd      other         red  32.590000 -85.480000
# 38        other   4wd      other      silver  32.590000 -85.480000
# 40        other   4wd     pickup        blue  32.590000 -85.480000
# 42        other   rwd      coupe         red  32.590000 -85.480000
# 45        other   4wd     pickup      silver  32.590000 -85.480000
# 49        other   4wd        SUV      silver  32.590000 -85.480000
# 54        other   fwd  hatchback       black  32.590000 -85.480000
# 55    automatic   4wd     pickup        blue  32.547500 -85.468200
# 56        other   4wd      other         red  32.590000 -85.480000
# 59    automatic   fwd   mini-van      silver  32.628739 -85.461820
# 63        other   rwd      other       black  32.590000 -85.480000
# 65       manual   rwd      truck       white  32.630400 -85.401600
# 68        other   4wd     pickup       brown  32.590000 -85.480000
# 72        other   4wd        SUV       white  32.590000 -85.480000
# 73    automatic   rwd      sedan        grey  32.822400 -85.770400

# %%
car_data = car_data.loc[car_data['price']>1200]
car_data = car_data.loc[car_data['price']<300000]

# %%
plt.plot(car_data.price.value_counts(), 'o', color='navy', alpha=0.2)
plt.title('Price distribution $1200-50,000')
plt.ylabel('Count')
plt.xlabel('price ($)')
plt.xlim(1200, 50000)
plt.show()
plt.clf()

# %%
car_data.price.describe()
# Out:
# count    186209.000000
# mean      19286.255439
# std       14498.309078
# min        1214.000000
# 25%        7995.000000
# 50%       15900.000000
# 75%       27250.000000
# max      289995.000000
# Name: price, dtype: float64

# %%
car_data=car_data.loc[car_data['price']>7000]
car_data=car_data.loc[car_data['price']<30000]

# %%
car_data.reset_index(inplace=True, drop=True)
strcols = ['manufacturer', 'model', 'fuel', 'transmission', 'drive', 'type', 'paint_color']
for col in strcols:
    car_data[col] = car_data[col].astype('string')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109650 entries, 0 to 109649
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         109650 non-null  int64
#  1   year          109650 non-null  float64
#  2   manufacturer  109650 non-null  string
#  3   model         109650 non-null  string
#  4   fuel          109650 non-null  string
#  5   odometer      109650 non-null  float64
#  6   transmission  109650 non-null  string
#  7   drive         109650 non-null  string
#  8   type          109650 non-null  string
#  9   paint_color   109650 non-null  string
#  10  lat           109650 non-null  float64
#  11  long          109650 non-null  float64
# dtypes: float64(4), int64(1), string(7)
# memory usage: 10.0 MB

# %%
plt.figure(figsize=(20,10))
plt.bar(car_data.manufacturer.unique(), car_data.manufacturer.value_counts(), color = c1)
plt.title('Manufacturer Distribution')
plt.xlabel('Manufacturer')
plt.xticks(rotation=30)
plt.ylabel('Count')
plt.show()
plt.clf()

# %%
car_data['model'] = car_data['model'].apply(lambda x: x.split(' ')[0].lower())

# %%
car_data.groupby('manufacturer').model.nunique()
# Out:
# manufacturer
# acura               16
# alfa-romeo           1
# audi                26
# bmw                130
# buick               35
# cadillac            43
# chevrolet          219
# chrysler            37
# datsun               8
# dodge               83
# fiat                12
# ford               192
# gmc                 90
# harley-davidson      2
# honda               36
# hyundai             24
# infiniti            49
# jaguar              25
# jeep                50
# kia                 25
# land rover           2
# lexus               56
# lincoln             25
# mazda               37
# mercedes-benz      140
# mercury             23
# mini                16
# mitsubishi          18
# nissan              52
# pontiac             30
# porsche             17
# ram                 51
# rover               19
# saturn               4
# subaru              19
# tesla                2
# toyota              73
# volkswagen          46
# volvo               28
# Name: model, dtype: int64

# %%
car_data.loc[car_data['manufacturer']=='ford'].model.unique()
# Out:
# array(['f-150', 'f250', 'f450', 'expedition', 'f150', 'ranger',
#        'thunderbird', 'c-max', 'escape', 'mustang', 'f-250', 'edge',
#        'transit', 'super', 'econoline', 'f-750', 'e-series', 'f-350',
#        'fusion', 'fairlane', 'explorer', 'f550', 'f800', 'flex', 'custom',
#        'focus', 'taurus', 'coupe', 'e150', 'f350', 'fiesta', 'ecosport',
#        'edgetitanium', 'f100', 'bronco', 'f-550', 'e', 'ranchero',
#        'excursion', 't', 'e-450', 'f650', 'f1', 'victoria', 'f750',
#        'f-650', 'e250', 'e-250', 'tudor', 'e350', 'f-450', 'anglia',
#        'maverick', 'f-100', 'sedan', 'svt', 'ltd', '150', 'crown',
#        'galaxie', 'e-350', 't-bucket', 'e450', 'pu', 'f', 'model', 'crew',
#        'pickup', 'f-330', 'regency', 'e-150', 'hotrod', 'ei', 'a', '68',
#        't-bird', 'falcon', 'c', 'superduty', 'aerostar', 'lcf', 'esape',
#        'cmax', 'utility', 'standard', 'xlt', 'fles', 'f250hd', 'f-1',
#        'truck', 'deluxe', '750', 'customline', 'f360', 'freestar',
#        'expadition', 'flat', 'transit-150', 'tbird', 'roadster',
#        'ecnoline', '3', 'excusrion', '250', 'five', 'cargo', 'grand',
#        'f8oo', 'f/8oo', 'f250xlt', 'step', 'police', 'expediton', 'fx4',
#        'runabout', 'f-350sd', 'workhorse', 'country', 'f/15o', 'f-250sd',
#        'galaxy', 'shelby', '350', 'mainline', 'coachmen', 'connect',
#        'lightning', 'f-', 'bus', 'f700', 'f3', '/vmi', 'torino', 'hot',
#        'hd', 'transit-350', 'transit-250', 'cf8000', 'st3', 'phaeton',
#        'e-350sd', 'sport', 'lifted', 'refrigerator', 'focust', 'explore',
#        'ecoline', 'f600', 'f-350.', 'mustanggt', 'skyliner', '550',
#        'f750sd', '23', 'l8000', 'model-t', 'street', 'tunderbird',
#        'f-1500', 'hightop', 'galazie', 'f4', '"t"', '2', 'and', 'f350sd',
#        '7', 'f700f', 't-150', 'expetion', 'club', 'exployer', 't350',
#        'f550hd', 'echosport', '-150', 'winstar', 'unibody', 'f-150xl',
#        'flax', 'econline', 'panel', 'mustan', 'c800', '3500', 'f35o',
#        'mustang,', 'elite', 'f150xlt', 'gran', 'f15o', 'f150,'],
#       dtype=object)

# %%
car_data.loc[car_data['manufacturer']=='chevrolet'].model.unique()
# Out:
# array(['colorado', 'silverado', 'bel', 'trax', 'malibu', 'camaro',
#        'sonic', 'express', '3500', 'cc4500', 'tahoe', 'equinox', 'ssr',
#        'traverse', 'aero', 'impala', 'c20', '210', 'cruze', 'c10',
#        'corvette', 'avalanche', 'elcamino', 'suburban', '1500', 'caprice',
#        'k-10', 'trailblazer', 'el', 'spark', 'bolt', 'astro', 'hhr',
#        'volt', 'g30', 'coupe', 'k5', 's-10', 'chevelle', 'gmt-400',
#        'captiva', 'blazer', 'nova', 'ambulance', 'k10', 'c-10', 'c7500',
#        'c6500', 'ii', 'scottsdale', 'brookwood', 'c5500', 'coe', 'wagon',
#        'camero', '2500', '3500hd', 'deluxe', 'corvair', 'w4500', 's10',
#        '3100', 'conversion', 'k', 'custom', 'master', '2500hd', 'w5500',
#        'vega', 'city', 'k20', 'c/k20', 'monte', 'roadster', '1-ton',
#        'styleline', 'cheyenne', 'c5', 'k3500', 'sport', 'biscayne',
#        'uplander', 'tracker', 'sedan', 'cruze,', 'malibu,', 'k1500',
#        'utility', 'business', 'pickup', 'k30', 'station', 'awd', 'death',
#        'c-20', 'c3500', 'silverado/sierra', 'c3500hd', 'high', 'g-series',
#        'belair', '(cng)', 'flatbed', 'c/k', 'truck', '1972', 'classic',
#        'z71', 'cavalier', 'other', 'crew', 'g20', 'avalanch', 'equinox`',
#        'c4500', 'maibu', 'comercial', 'p30', 'kodiak', 'g4500', 'bel-air',
#        'c30', 'cruz', 'van', '15-pass.', 'sivlerado', 'cruise', 'duramax',
#        'cobalt', 'impalalt', 'pu', 'sliverado', 'c2500', 'topkick',
#        'r3500', 'venture', 'delray', 'ss454', 'mailbu', 'camaro1lt',
#        'k-20', '8500', 'tilt', 'g10', '4500', 'c1500', 'short',
#        'stylemaster', 'cruse', 'imapla', 'dilverado', 'travese', 'monza',
#        'apache', '4', 'lumina', 'si;verado', 'ltz', '(210)', 'c-5500',
#        '1954', '7500', 'fleetmaster', 'avalache', 'c/10', 'capitol',
#        'black', 'ss', 'z28', '2', '5', '4x4', 'c', 'swb', 'supreme',
#        'sil', 'eqinox', 'panel', 'cc7h042', 'v8', '2509', 'citation',
#        'hd', 'k2500hd', 'capiva', '1', '3/4', 'g3500', 'g2500',
#        'traversa', 'convertible', 'siverado', 'raverse', 'pick-up', 'r/v',
#        'aveo', 'stingray', 'acadia', 'step', 'pannel', '4-dr', 'ex-cab',
#        '5500', 'g', 'asto', 'sinic', 'travers', 'powerglide', 'k2500',
#        'c10/k10', 'pick', 'k3500hd', 'c/t', 'del', 'npr', 'two', 'c70',
#        'susburban', 'scottdale'], dtype=object)

# %%
car_data.drop(columns='model', inplace=True)

# %%
plt.figure(figsize=(20,10))
plt.plot(car_data.groupby('type').price.mean())

# %%
plt.figure(figsize=(20,10))
plt.bar(['SUV', 'bus', 'convertible', 'coupe', 'hatchback', 'mini-van', 'offroad', 'other', 'pickup', 'sedan', 'truck', 'van', 'wagon'], car_data.groupby('type').price.mean(),color=n2)
plt.title('Price by type')
plt.ylabel('Price ($)')
plt.xlabel('type')
plt.ylim(12500, 22000)
plt.show()
plt.clf()

# %%
car_data.drive.unique()
# Out:
# <StringArray>
# ['rwd', '4wd', 'fwd']
# Length: 3, dtype: string

# %%
drive_counts = car_data.drive.value_counts(normalize=True)
labels = ['rwd', 'fwd', '4wd']
triop = ['grey', '#1f77b4', 'orange']
trio = ['#6b6b6b', '#ffa500', '#1f77b4']
explode = [0.02, 0.02, 0.02]
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
axs[0].pie(drive_counts, labels=labels, colors=trio, explode=explode, autopct='%1.1f%%')
axs[0].set_title('Drive Distribution')

drive_price = car_data.groupby(car_data['drive']).price.mean()
sorted_drive_price = drive_price.sort_values(ascending=False)

axs[1].bar(sorted_drive_price.index, sorted_drive_price.values, color = triop)
axs[1].set_title('Avg. Price')
axs[1].set_ylabel('Avg. Price($)')
plt.show()

# %%
car_data.drop(columns='drive', inplace=True)

# %%
gear_counts = car_data.loc[car_data.transmission != 'other'].transmission.value_counts(normalize=True)
labels = ['Manual', 'Automatic']

explode = [0.1, 0.1]
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
axs[0].pie(gear_counts, labels=['Manual', 'Automatic'], colors=b2, explode=explode, autopct='%1.1f%%')
axs[0].set_title('Transmission Type Distribution')

gear_price = car_data.groupby(car_data.loc[car_data.transmission != 'other']['transmission']).price.mean()
sorted_gear_price = gear_price.sort_values(ascending=False)

# create bar plot
axs[1].bar(sorted_gear_price.index.astype(str), sorted_gear_price.values, color = b1)

# add value labels to the bars
for i, v in enumerate(sorted_gear_price.values):
    axs[1].text(i, v, '${:.0f}'.format(v), ha='center', va='bottom')

axs[1].set_title('Avg. Price')
axs[1].set_ylabel('Avg. Price($)')

plt.show()

manual_price = car_data.loc[car_data.transmission == 'manual', 'price'].mean()
auto_price = car_data.loc[car_data.transmission == 'automatic', 'price'].mean()

print('Manual transmission mean price: $' + str(int(manual_price)))
print(f'Automatic transmission mean price: $' + str(int(auto_price)))
# Out:
# Manual transmission mean price: $15920
# Automatic transmission mean price: $16014

# %%
car_data.drop(columns='transmission', inplace=True)

# %%
plt.bar(car_data.fuel.unique(), car_data.fuel.value_counts(), color=n1)
plt.title('Fuel types distribution')
plt.xlabel('Fuel type')
plt.ylabel('Value counts')
plt.show()

# %%
plt.bar(['diesel', 'electric', 'gas', 'hybrid', 'other'], car_data.groupby('fuel').price.mean(), color=['red', 'crimson', 'tomato', 'orange', 'yellow'], alpha=0.6)
plt.title('Fuel price mean')
plt.xlabel('Fuel type')
plt.ylabel('Price ($)')
plt.show()
car_data.groupby('fuel').price.mean()
alpha=0.6

# %%
car_data.loc[car_data['fuel']=='electric'].head(50)
# Out:
#       price    year manufacturer      fuel  odometer       type paint_color  \
# 204   29890  2013.0        tesla  electric   61591.0      sedan        grey
# 340   29890  2013.0        tesla  electric   61591.0      sedan        grey
# 680   29890  2013.0        tesla  electric   61591.0      sedan        grey
# 849   29890  2013.0        tesla  electric   61591.0      sedan        grey
# 1559  22995  2017.0    chevrolet  electric   42331.0      sedan      silver
# 1628  22995  2017.0    chevrolet  electric   42331.0      sedan      silver
# 1822  22995  2017.0    chevrolet  electric   42331.0      sedan      silver
# 1881  22995  2017.0    chevrolet  electric   42331.0      sedan      silver
# 1955  22995  2017.0    chevrolet  electric   42331.0      sedan      silver
# 2282  14499  2017.0          kia  electric   32590.0      wagon       black
# 2389  14499  2017.0          kia  electric   32590.0      wagon       black
# 2739  14499  2017.0          kia  electric   32590.0      wagon       black
# 2891  22995  2017.0    chevrolet  electric   27000.0  hatchback        blue
# 2893  17495  2018.0          kia  electric   36750.0  hatchback        grey
# 2894  14499  2017.0          kia  electric   32590.0      wagon       black
# 2903  14499  2017.0          kia  electric   32590.0      wagon       black
# 2906  24995  2019.0       nissan  electric    5650.0      other       white
# 3090  14990  2015.0       nissan  electric   26816.0  hatchback       white
# 3308  29999  2013.0        tesla  electric   61467.0      sedan        blue
# 3376  15899  2016.0          bmw  electric   37838.0      sedan        grey
# 3404  28990  2019.0          kia  electric    7666.0      wagon       white
# 3515  24990  2020.0    chevrolet  electric    5670.0  hatchback        blue
# 3699  25590  2019.0      hyundai  electric   21536.0  hatchback       white
# 3710  15990  2016.0   volkswagen  electric   15528.0      sedan       white
# 3772  28590  2019.0          kia  electric   10230.0      wagon      silver
# 3811  10649  2016.0    chevrolet  electric   23754.0  hatchback      custom
# 3885  28990  2018.0          bmw  electric   12514.0  hatchback        blue
# 4030  29990  2013.0        tesla  electric   59613.0      sedan        blue
# 4161  12590  2015.0    chevrolet  electric   25817.0  hatchback      silver
# 4186  14990  2017.0         ford  electric   27724.0  hatchback      silver
# 4208  12590  2016.0    chevrolet  electric   26063.0  hatchback      silver
# 4231  11990  2014.0         ford  electric   45308.0  hatchback        blue
# 4568  29990  2013.0        tesla  electric   59613.0      sedan        blue
# 4720  16752  2018.0          kia  electric   13507.0      wagon      silver
# 5097  17990  2017.0      hyundai  electric   44162.0  hatchback       black
# 5359  28590  2019.0          kia  electric   10230.0      wagon      silver
# 5938  14590  2016.0         ford  electric   17358.0  hatchback       white
# 5939  14990  2016.0         ford  electric    3712.0  hatchback       white
# 5991  14990  2015.0       nissan  electric   26816.0  hatchback       white
# 6102  29990  2013.0        tesla  electric   59613.0      sedan        blue
# 6289  19990  2019.0       nissan  electric   14010.0  hatchback        blue
# 6414  14990  2017.0         ford  electric   27724.0  hatchback      silver
# 6434  16990  2018.0       nissan  electric   25234.0  hatchback        blue
# 6449  11000  2014.0    chevrolet  electric  113000.0      sedan      silver
# 6610  29990  2013.0        tesla  electric   59613.0      sedan        blue
# 7028  19990  2019.0       nissan  electric   14010.0  hatchback        blue
# 7125  29990  2013.0        tesla  electric   59613.0      sedan        blue
# 7737  28590  2019.0          kia  electric   10230.0      wagon      silver
# 7824  12590  2015.0    chevrolet  electric   25817.0  hatchback      silver
# 8372  24995  2017.0          bmw  electric   23643.0      sedan        blue
#
#             lat        long
# 204   33.669601  -86.817617
# 340   33.669601  -86.817617
# 680   33.669601  -86.817617
# 849   33.669601  -86.817617
# 1559  61.569390 -149.356450
# 1628  61.569390 -149.356450
# 1822  61.569390 -149.356450
# 1881  61.569390 -149.356450
# 1955  61.569390 -149.356450
# 2282  61.211600 -149.876100
# 2389  61.211600 -149.876100
# 2739  61.211600 -149.876100
# 2891  58.362800 -134.529400
# 2893  58.362800 -134.529400
# 2894  61.211600 -149.876100
# 2903  61.211600 -149.876100
# 2906  58.362800 -134.529400
# 3090  33.786500  -84.445400
# 3308  33.618615 -111.922263
# 3376  33.422700 -111.926100
# 3404  33.500000 -112.050000
# 3515  33.440000 -112.080000
# 3699  33.500000 -112.050000
# 3710  33.500000 -112.050000
# 3772  33.440000 -111.800000
# 3811  33.338295 -111.934644
# 3885  33.440000 -112.080000
# 4030  33.440000 -111.800000
# 4161  34.620000 -112.420000
# 4186  34.620000 -112.420000
# 4208  34.620000 -112.420000
# 4231  34.620000 -112.420000
# 4568  32.210000 -110.960000
# 4720  32.271329 -110.993712
# 5097  32.210000 -110.960000
# 5359  32.210000 -110.960000
# 5938  34.720000  -92.350000
# 5939  34.720000  -92.350000
# 5991  34.720000  -92.350000
# 6102  35.380000 -119.020000
# 6289  35.380000 -119.020000
# 6414  35.380000 -119.020000
# 6434  35.380000 -119.020000
# 6449  35.386600 -119.017100
# 6610  39.710000 -121.810000
# 7028  33.779214  -84.411811
# 7125  33.779214  -84.411811
# 7737  33.779214  -84.411811
# 7824  33.779214  -84.411811
# 8372  34.125050 -118.255460

# %%
plt.figure(figsize=(20,10))
plt.plot(car_data.groupby('paint_color').price.mean())

# %%
car_data['year'] = car_data.year.astype('int')
plt.bar(car_data.year.unique(), car_data.year.value_counts(), color='Green')
plt.title('Production year distribution')
plt.xlabel('Year')
plt.ylabel('Instances')
plt.show()

# %%
car_data = car_data.loc[car_data['year']>=2001]
car_data = car_data.loc[car_data['year']<=2020]

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104541 entries, 0 to 109649
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         104541 non-null  int64
#  1   year          104541 non-null  int32
#  2   manufacturer  104541 non-null  string
#  3   fuel          104541 non-null  string
#  4   odometer      104541 non-null  float64
#  5   type          104541 non-null  string
#  6   paint_color   104541 non-null  string
#  7   lat           104541 non-null  float64
#  8   long          104541 non-null  float64
# dtypes: float64(3), int32(1), int64(1), string(4)
# memory usage: 7.6 MB

# %%
car_data['year'] = car_data.year.astype('int')
cmap = plt.cm.get_cmap('Greens')
bars = plt.bar(car_data.year.unique(), car_data.year.value_counts(), color=cmap(car_data.year.value_counts()/max(car_data.year.value_counts())))
plt.title('Production year distribution')
plt.xlabel('Year')
plt.xticks(np.arange(2001, 2021, step=1), rotation=-20, fontsize=6)
plt.ylabel('Instances')
plt.show()

# %%
# removing outliers
car_data = car_data.loc[car_data['odometer']<350000]

# %%
def odo_range(df, col_name):
    # Define the price ranges
    odo_ranges = np.arange(0, 1000001, 10000)
    
    # Define a function to assign the price ranges
    def get_odo_range(miles):
        for i in range(len(odo_ranges)-1):
            if odo_ranges[i] <= miles < odo_ranges[i+1]:
                return f"{odo_ranges[i]/1000}k-{odo_ranges[i+1]/1000}k mi."
    
    # Apply the function to the specified column
    odo_range = df[col_name].apply(get_odo_range)
    
    return odo_range

# %%
odom = odo_range(car_data, 'odometer')

# %%
plt.figure(figsize=(15,10))
cmap = plt.cm.get_cmap('Blues')
plt.barh(odom.unique(), odom.value_counts(), color = cmap(odom.value_counts()/max(odom.value_counts())))
plt.xticks(rotation=45)
plt.xlabel('Instances')
plt.ylabel('Miles Driven')
plt.show()

# %%
car_data = car_data.loc[car_data['odometer']>1000]

# %%
odometer = car_data['odometer']
print("Summary statistics for the 'odometer' column:")
print(f"Mean: {odometer.mean():,.0f} miles")
print(f"Standard deviation: {odometer.std():,.0f} miles")
print(f"Minimum value: {odometer.min():,.0f} miles")
print(f"25th percentile: {np.percentile(odometer, 25):,.0f} miles")
print(f"Median: {np.median(odometer):,.0f} miles")
print(f"75th percentile: {np.percentile(odometer, 75):,.0f} miles")
print(f"Maximum value: {odometer.max():,.0f} miles")
# Out:
# Summary statistics for the 'odometer' column:
# Mean: 89,750 miles
# Standard deviation: 52,931 miles
# Minimum value: 1,007 miles
# 25th percentile: 46,218 miles
# Median: 86,400 miles
# 75th percentile: 123,456 miles
# Maximum value: 349,525 miles

# %%
pd.options.display.max_columns = None
corr = car_data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\jonne\miniconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# <style type="text/css">
# #T_f8f95_row0_col0, #T_f8f95_row1_col1, #T_f8f95_row2_col2, #T_f8f95_row3_col3, #T_f8f95_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f8f95_row0_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_f8f95_row0_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f8f95_row0_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f8f95_row0_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f8f95_row1_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f8f95_row1_col2, #T_f8f95_row2_col0, #T_f8f95_row2_col1, #T_f8f95_row3_col4, #T_f8f95_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f8f95_row1_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f8f95_row1_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f8f95_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f8f95_row2_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f8f95_row3_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f8f95_row3_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f8f95_row3_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f8f95_row4_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f8f95_row4_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f8f95_row4_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_f8f95_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >odometer</th>
#       <th class="col_heading level0 col3" >lat</th>
#       <th class="col_heading level0 col4" >long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8f95_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_f8f95_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_f8f95_row0_col1" class="data row0 col1" >0.43</td>
#       <td id="T_f8f95_row0_col2" class="data row0 col2" >-0.42</td>
#       <td id="T_f8f95_row0_col3" class="data row0 col3" >-0.02</td>
#       <td id="T_f8f95_row0_col4" class="data row0 col4" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_f8f95_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_f8f95_row1_col0" class="data row1 col0" >0.43</td>
#       <td id="T_f8f95_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_f8f95_row1_col2" class="data row1 col2" >-0.60</td>
#       <td id="T_f8f95_row1_col3" class="data row1 col3" >-0.05</td>
#       <td id="T_f8f95_row1_col4" class="data row1 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_f8f95_level0_row2" class="row_heading level0 row2" >odometer</th>
#       <td id="T_f8f95_row2_col0" class="data row2 col0" >-0.42</td>
#       <td id="T_f8f95_row2_col1" class="data row2 col1" >-0.60</td>
#       <td id="T_f8f95_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_f8f95_row2_col3" class="data row2 col3" >0.03</td>
#       <td id="T_f8f95_row2_col4" class="data row2 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f8f95_level0_row3" class="row_heading level0 row3" >lat</th>
#       <td id="T_f8f95_row3_col0" class="data row3 col0" >-0.02</td>
#       <td id="T_f8f95_row3_col1" class="data row3 col1" >-0.05</td>
#       <td id="T_f8f95_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_f8f95_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_f8f95_row3_col4" class="data row3 col4" >-0.16</td>
#     </tr>
#     <tr>
#       <th id="T_f8f95_level0_row4" class="row_heading level0 row4" >long</th>
#       <td id="T_f8f95_row4_col0" class="data row4 col0" >-0.04</td>
#       <td id="T_f8f95_row4_col1" class="data row4 col1" >0.01</td>
#       <td id="T_f8f95_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_f8f95_row4_col3" class="data row4 col3" >-0.16</td>
#       <td id="T_f8f95_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
